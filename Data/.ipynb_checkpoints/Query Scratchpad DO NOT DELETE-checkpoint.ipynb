# %%
from flask import Flask, jsonify
from sqlalchemy import create_engine
import os
import numpy as np
import json
from decimal import Decimal 
from convert2geojson import Convert2GeoJson

# %%
rds_connection_string = "postgresql://vzgrmmdttkwsnk:5b0f5e6c07de8fc1c547861230ed3726ec9a09021f0e40db1cd92c4a119d1bce@ec2-52-86-56-90.compute-1.amazonaws.com:5432/df4j8v6ob22efh"
engine = create_engine(rds_connection_string)
conn = engine.connect()

# %%
# Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine
from sqlalchemy.dialects import registry

# Create Engine for data
database_path = "postgresql://vzgrmmdttkwsnk:5b0f5e6c07de8fc1c547861230ed3726ec9a09021f0e40db1cd92c4a119d1bce@ec2-52-86-56-90.compute-1.amazonaws.com:5432/df4j8v6ob22efh"
engine = create_engine(database_path)
conn = engine.connect()

# %%
zip_data = pd.read_sql("SELECT * FROM zips", conn)
zip_data.head()
# Out:
#   us_zip_code      type primary_city state latitude longitude          county  \
# 0       00501    UNIQUE   Holtsville    NY    40.81    -73.04  Suffolk County
# 1       00602  STANDARD       Aguada    PR    18.38    -67.18              NA
# 2       00601  STANDARD     Adjuntas    PR    18.16    -66.72        Adjuntas
# 3       00544    UNIQUE   Holtsville    NY    40.81    -73.04  Suffolk County
# 4       00603  STANDARD    Aguadilla    PR    18.43    -67.15       Aguadilla
#
#               timezone area_codes country  estimated_population  \
# 0     America/New_York        631      US                   384
# 1                    0        787      US                     0
# 2  America/Puerto_Rico     787939      US                     0
# 3     America/New_York        631      US                     0
# 4  America/Puerto_Rico        787      US                     0
#
#                         created_at                       updated_at
# ...

# %%
zip_data['primary_city'].nunique()
# Out:
# 18758

# %%
pet_data = pd.read_sql("SELECT * FROM dogfriendly", conn)
pet_data
# Out:
#     overall_rank        city state  total_score  pet_budget  pet_health  \
# 0              1  Scottsdale    AZ        63.28          71           1
# 1              2       Tampa    FL        62.25          42           5
# 2              3     Orlando    FL        62.20          31           3
# 3              4   Las Vegas    NV        60.48          32          34
# 4              5  Birmingham    AL        59.81           9          15
# ..           ...         ...   ...          ...         ...         ...
# 95            96     Detroit    MI        42.11          33          98
# 96            97      Fresno    CA        42.10          75          90
# 97            98      Newark    NJ        41.99          88          32
# 98            99    Honolulu    HI        39.76          84          99
# 99           100   Santa Ana    CA        36.22          98          76
#
#     outdoor_friendliness
# 0                      3
# 1                     13
# ...

# %%
test = pd.read_sql("SELECT DISTINCT(primary_city)")

# %%
test4 = pd.read_sql("""SELECT s2.primary_city, s2.latitude, MAX(s2.longitude) as longitude
FROM ( 
    select primary_city, max(latitude) as latitude
    FROM zips 
    GROUP BY primary_city
) s1 
INNER JOIN zips s2 ON s2.primary_city=s1.primary_city AND s2.latitude = s1.latitude
GROUP BY s2.primary_city, s2.latitude """, conn)

# %%
final_dog_query = pd.read_sql('SELECT mastercity.primary_city, mastercity.latitude, mastercity.longitude, dogfriendly.overall_rank, dogfriendly.total_score FROM mastercity INNER JOIN dogfriendly ON mastercity.primary_city=dogfriendly.city', conn)

# %%
data = engine.execute('SELECT mastercity.primary_city, mastercity.latitude, mastercity.longitude, dogfriendly.overall_rank FROM mastercity INNER JOIN dogfriendly ON mastercity.primary_city=dogfriendly.city')
data2 = pd.DataFrame(data)
data2
# Out:
#                  0      1        2   3
# 0      Albuquerque  35.11  -106.62  14
# 1          Anaheim  33.86  -117.74  93
# 2        Anchorage  61.45  -150.63  89
# 3        Arlington  48.18  -121.67  69
# 4          Atlanta     45   -84.15  12
# ..             ...    ...      ...  ..
# 90          Tucson  32.54  -110.95  30
# 91           Tulsa  36.15   -95.99  27
# 92  Virginia Beach  36.78   -76.08  60
# 93      Washington  44.27   -69.36  61
# 94         Wichita  37.68   -97.34  76
#
# [95 rows x 4 columns]

# %%
data3 = data2.rename(columns={0: 'primary_city', 1: 'latitude', 2: 'longitude', 3: 'overall_score'})

# %%
data3["latitude"] = data3["latitude"].astype(float)
data3["longitude"] = data3["longitude"].astype(float)
data4 = Convert2GeoJson(
          data3,
          data3.columns,
          lat= 'latitude',
          lon= 'longitude')
data5 = data4.geojson()

# %%
print(data3)
# Out:
#       primary_city  latitude  longitude  overall_score
# 0      Albuquerque     35.11    -106.62             14
# 1          Anaheim     33.86    -117.74             93
# 2        Anchorage     61.45    -150.63             89
# 3        Arlington     48.18    -121.67             69
# 4          Atlanta     45.00     -84.15             12
# ..             ...       ...        ...            ...
# 90          Tucson     32.54    -110.95             30
# 91           Tulsa     36.15     -95.99             27
# 92  Virginia Beach     36.78     -76.08             60
# 93      Washington     44.27     -69.36             61
# 94         Wichita     37.68     -97.34             76
#
# [95 rows x 4 columns]
