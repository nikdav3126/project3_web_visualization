# %%
 # Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine
from sqlalchemy.dialects import registry

# Create Engine for data
database_path = "postgresql://vzgrmmdttkwsnk:5b0f5e6c07de8fc1c547861230ed3726ec9a09021f0e40db1cd92c4a119d1bce@ec2-52-86-56-90.compute-1.amazonaws.com:5432/df4j8v6ob22efh"
engine = create_engine(database_path)
conn = engine.connect()

# %%
happiestcities = pd.read_sql("SELECT * FROM happiestCities", conn)
happiestcities
# Out:
#      overall_rank           city state  total_score  emotional_physical  \
# 0               1        Fremont    CA        77.13                   1
# 1               2       Columbia    MD        71.64                   3
# 2               3  San Francisco    CA        71.15                   4
# 3               4       San Jose    CA        71.00                   2
# 4               5         Irvine    CA        70.38                   5
# ..            ...            ...   ...          ...                 ...
# 177           178     Montgomery    AL        35.54                 174
# 178           179     Huntington    WV        35.53                 182
# 179           180        Memphis    TN        34.86                 176
# 180           181       Gulfport    MS        34.71                 181
# 181           182        Detroit    MI        32.31                 179
#
#      income_employment  community_environment
# 0                   46                      2
# ...

# %%
zip_data = pd.read_sql("SELECT * FROM zips", conn)
zip_data.head()
# Out:
#   us_zip_code      type primary_city state latitude longitude          county  \
# 0       00501    UNIQUE   Holtsville    NY    40.81    -73.04  Suffolk County
# 1       00602  STANDARD       Aguada    PR    18.38    -67.18              NA
# 2       00601  STANDARD     Adjuntas    PR    18.16    -66.72        Adjuntas
# 3       00544    UNIQUE   Holtsville    NY    40.81    -73.04  Suffolk County
# 4       00603  STANDARD    Aguadilla    PR    18.43    -67.15       Aguadilla
#
#               timezone area_codes country  estimated_population  \
# 0     America/New_York        631      US                   384
# 1                    0        787      US                     0
# 2  America/Puerto_Rico     787939      US                     0
# 3     America/New_York        631      US                     0
# 4  America/Puerto_Rico        787      US                     0
#
#                         created_at                       updated_at
# ...

# %%
pet_data = pd.read_sql("SELECT * FROM dogfriendly", conn)
pet_data
# Out:
#     overall_rank        city state  total_score  pet_budget  pet_health  \
# 0              1  Scottsdale    AZ        63.28          71           1
# 1              2       Tampa    FL        62.25          42           5
# 2              3     Orlando    FL        62.20          31           3
# 3              4   Las Vegas    NV        60.48          32          34
# 4              5  Birmingham    AL        59.81           9          15
# ..           ...         ...   ...          ...         ...         ...
# 95            96     Detroit    MI        42.11          33          98
# 96            97      Fresno    CA        42.10          75          90
# 97            98      Newark    NJ        41.99          88          32
# 98            99    Honolulu    HI        39.76          84          99
# 99           100   Santa Ana    CA        36.22          98          76
#
#     outdoor_friendliness
# 0                      3
# 1                     13
# ...

# %%
petLatLng = pd.read_sql(
    "SELECT zips.us_zip_code, zips.primary_city, dogfriendly.overall_rank, dogfriendly.total_score, dogfriendly.pet_budget, dogfriendly.pet_health, dogfriendly.outdoor_friendliness FROM zips JOIN dogfriendly ON zips.primary_city=dogfriendly.city", conn)
#petLatLng.sort_values("primary_city", inplace = True)
petLatLng.drop_duplicates(subset=["overall_rank"], inplace = True)
#petLatLng.sort_values(by="total_score", ascending  = False)
petLatLng.to_csv("test")

# %%
happiestLatLng = pd.read_sql(
    "SELECT zips.primary_city, happiestcities.overall_rank, zips.latitude, zips.longitude, happiestcities.total_score FROM zips JOIN happiestcities ON zips.primary_city=happiestcities.city", conn)
happiestLatLng.sort_values("primary_city", inplace = True)
happiestLatLng.drop_duplicates(subset=["primary_city"], inplace = True)
happiestLatLng.sort_values(by="primary_city")
happiestLatLng
# Out:
#      primary_city  overall_rank latitude longitude  total_score
# 5674        Akron           165    40.16   -103.21        42.29
# 6124  Albuquerque           121    35.11   -106.62        50.31
# 5458     Amarillo           143     35.2   -101.81        46.75
# 6697      Anaheim            20    33.86   -117.74        63.72
# 7518    Anchorage            59     61.2   -149.74        58.18
# ...           ...           ...      ...       ...          ...
# 855    Washington            85    38.89    -77.03        55.05
# 4268      Wichita           141    37.68    -97.34        46.78
# 1698   Wilmington           115    34.21    -77.91        50.64
# 34      Worcester           110    42.26     -71.8        51.69
# 483       Yonkers            44    40.94    -73.86        59.69
#
# [169 rows x 5 columns]
